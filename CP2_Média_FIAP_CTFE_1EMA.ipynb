# %% [markdown]
# <a href="https://colab.research.google.com/github/0megaAD/mediafiap/blob/main/CP2_M%C3%A9dia_FIAP_CTFE_1EMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calcularmediacps():
  cps = int(input("Quantas CP's Tem?: "))
  if cps >= 3:
    notas_cp = []

    for i in range(cps):
      CP_1 = float(input(f"Qual a nota da CP {i + 1}?: "))
      notas_cp.append(CP_1)

    notas_cp.sort(reverse=True)
    media_cp = (sum(notas_cp[:2])/2) * 0.2
    return media_cp
  else:
    return "Coloque no minimo 3 CPS"

# %%
def calcularmediasprint():
  print("---------------------------")
  spring1 = float(input("Insira o valor da 1° Sprint: "))
  spring2 = float(input("Insira o valor da 2° Sprint: "))
  print("---------------------------")

  spring = ((spring1 + spring2) / 2) * 0.2

  return spring

# %%
def calcularmediafinal(mediaglobal):

  media_cp = calcularmediacps()
  media_sprint = calcularmediasprint()

  media_parcial = media_cp + media_sprint

  if media_parcial >= 6:
      print("---------------------------")
      print(f"Sua média parcial é {media_parcial:.2f}, você já atingiu o mínimo!")
      print("---------------------------")
  else:
      print("---------------------------")
      print(f"Sua média parcial é {media_parcial:.2f}, faltam {6 - media_parcial:.2f} pontos")
      print("---------------------------")

  media_final = media_cp + media_sprint + mediaglobal
  return media_final

# %%
mediaglobal = float(input("Insira o valor da Global Solution: ")) * 0.6

print("---------------------------")
print("1°Semestre")
print("---------------------------")
media1 = calcularmediafinal(mediaglobal) * 0.4

print("---------------------------")
print("2°Semestre")
print("---------------------------")
media2 = calcularmediafinal(mediaglobal) * 0.6

media_final = media1 + media2

if media_final >= 6:
  print("---------------------------")
  print("Aprovado")
  print("---------------------------")
elif media_final >= 4:
  print("---------------------------")
  print("Exame")
  print("---------------------------")
  nota_exame = float(input("Insira a nota do exame: "))
  if ((media_final + nota_exame) / 2) >= 6:
    print("---------------------------")
    print("Aprovado")
    print("---------------------------")
  else:
    print("---------------------------")
    print("Reprovado")
    print("---------------------------")
else:
  print("---------------------------")
  print("Reprovado")
  print("---------------------------")
# Out:
# Insira o valor da Global Solution: 70
# ---------------------------
# 1°Semestre
# ---------------------------
# Quantas CP's Tem?: 3
# Qual a nota da CP 1?: 10
# Qual a nota da CP 2?: 10
# Qual a nota da CP 3?: 10
# ---------------------------
# Insira o valor da 1° Sprint: 10
# Insira o valor da 2° Sprint: 10
# ---------------------------
# ---------------------------
# Sua média parcial é 4.00, faltam 2.00 pontos
# ---------------------------
# ---------------------------
# 2°Semestre
# ---------------------------
# Quantas CP's Tem?: 3
# Qual a nota da CP 1?: 10
# Qual a nota da CP 2?: 2
# Qual a nota da CP 3?: 5
# ---------------------------
# Insira o valor da 1° Sprint: 10
# Insira o valor da 2° Sprint: 9
# ---------------------------
# ---------------------------
# Sua média parcial é 3.40, faltam 2.60 pontos
# ---------------------------
# ---------------------------
# Aprovado
# ---------------------------
